# %%
import entrezpy.esearch.esearcher
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import requests
import io

# %%
def extract_taxonomy(refseq):
    
    requestURL = f"https://www.ebi.ac.uk/proteins/api/uniparc/dbreference/{refseq:s}?offset=0&size=100&rfDdtype=RefSeq"

    r = requests.get(requestURL, headers={ "Accept" : "application/json"})

    if not r.ok:
        r.raise_for_status()
    
    try:
        uniparc_info = r.json()[0]
    except IndexError:
        return None
    try:
        for item in uniparc_info['dbReference'][0]['property']:
            if item["type"] == "NCBI_taxonomy_id":
                return int(item['value'])
    except KeyError:
        return None
    
def extract_taxid_from_name(refseq):
    
    url = f"https://rest.ensembl.org/taxonomy/name/{refseq}"
    #print (requestURL)

    r = requests.get(url, headers={ "Accept" : "application/json"})
    if not r.ok:
        return None
    data = r.json()
    return data

def get_taxID(taxa_info):
    if taxa_info is None:
        return None
    else:
        return taxa_info[0]['id']
    
def get_taxonomic_lineage(idx):
    """
    """
    url = f"https://rest.ensembl.org//taxonomy/classification/{idx}?"

    r = requests.get(url, headers={ "Accept" : "application/json"})
    if not r.ok:
        return None
    data = r.json()
    return data

def get_scientific_name(idx):
    """
    """
    url = f"https://rest.ensembl.org/taxonomy/id/{idx}?"

    r = requests.get(url, headers={ "Accept" : "application/json"})
    if not r.ok:
        return None
    data = r.json()
    return data['name']

def get_superkingdom(lineage):
    if lineage is None:
        return None
    else:
        return lineage[-1]['scientific_name']

def get_phylum(lineage):
    if lineage is None:
        return None
    else:
        try:
            return lineage[-2]['scientific_name']
        except:
            return None
    
def get_class(lineage):
    if lineage is None:
        return None
    else:
        try:
            return lineage[-3]['scientific_name']
        except:
            return None

def get_order(lineage):
    if lineage is None:
        return None
    else:
        try:
            return lineage[-4]['scientific_name']
        except:
            return None
        
def get_family(lineage):
    if lineage is None:
        return None
    else:
        try:
            return lineage[-5]['scientific_name']
        except:
            return None

# %%
HFSP_phy_genome_org_df = pd.read_csv("/mnt/researchdrive/Kaustubh/HFSP-Flagellar_proteins/data/sequences/uniq_genome_accession_organism_name_mapping.csv", header=None)
HFSP_phy_genome_org_df.columns = ["Genome_acc_id", "Organism_Name"]
HFSP_phy_genome_org_df
# Out:
#        Genome_acc_id                               Organism_Name
# 0    GCF_000005845.2   Escherichia_coli_str._K-12_substr._MG1655
# 1    GCF_000006765.1                 Pseudomonas_aeruginosa_PAO1
# 2    GCF_000007985.2                Geobacter_sulfurreducens_PCA
# 3    GCF_000008625.1                        Aquifex_aeolicus_VF5
# 4    GCF_000009045.1  Bacillus_subtilis_subsp._subtilis_str._168
# ..               ...                                         ...
# 131  GCF_023016405.1          Treponema_pallidum_subsp._pallidum
# 132  GCF_900093645.1      Chlamydiales_bacterium_SCGC_AB-751-O23
# 133  GCF_900097105.1                    Akkermansia_glycaniphila
# 134  GCF_900169565.1                         Nitrospira_japonica
# 135  GCF_900187105.1                         Eikenella_corrodens
#
# [136 rows x 2 columns]

# %%
HFSP_phy_genome_org_df["Taxa_info"] = HFSP_phy_genome_org_df["Organism_Name"].apply(extract_taxid_from_name)
HFSP_phy_genome_org_df["Taxa_id"] = HFSP_phy_genome_org_df["Taxa_info"].apply(get_taxID)
HFSP_phy_genome_org_df["lineage"] = HFSP_phy_genome_org_df["Taxa_id"].apply(get_taxonomic_lineage)
HFSP_phy_genome_org_df["superkingdom"] = HFSP_phy_genome_org_df["lineage"].apply(get_superkingdom)
HFSP_phy_genome_org_df["phylum"] = HFSP_phy_genome_org_df["lineage"].apply(get_phylum)
HFSP_phy_genome_org_df["class"] = HFSP_phy_genome_org_df["lineage"].apply(get_class)
HFSP_phy_genome_org_df["order"] = HFSP_phy_genome_org_df["lineage"].apply(get_order)
HFSP_phy_genome_org_df["family"] = HFSP_phy_genome_org_df["lineage"].apply(get_family)

# %%
HFSP_phy_genome_org_df
# Out:
#        Genome_acc_id                               Organism_Name  \
# 0    GCF_000005845.2   Escherichia_coli_str._K-12_substr._MG1655
# 1    GCF_000006765.1                 Pseudomonas_aeruginosa_PAO1
# 2    GCF_000007985.2                Geobacter_sulfurreducens_PCA
# 3    GCF_000008625.1                        Aquifex_aeolicus_VF5
# 4    GCF_000009045.1  Bacillus_subtilis_subsp._subtilis_str._168
# ..               ...                                         ...
# 131  GCF_023016405.1          Treponema_pallidum_subsp._pallidum
# 132  GCF_900093645.1      Chlamydiales_bacterium_SCGC_AB-751-O23
# 133  GCF_900097105.1                    Akkermansia_glycaniphila
# 134  GCF_900169565.1                         Nitrospira_japonica
# 135  GCF_900187105.1                         Eikenella_corrodens
#
#                                              Taxa_info  Taxa_id  \
# 0    [{'tags': {'synonym': ['Escherichia coli MG165...   511145
# 1    [{'tags': {'name': ['Pseudomonas aeruginosa PA...   208964
# 2    [{'parent': {'id': '35554', 'tags': {'name': [...   243231
# 3    [{'leaf': 1, 'id': '224324', 'scientific_name'...   224324
# 4    [{'id': '224308', 'children': [{'tags': {'equi...   224308
# ..                                                 ...      ...
# 131  [{'name': 'Treponema pallidum subsp. pallidum'...      161
# 132  [{'name': 'Chlamydiales bacterium SCGC AB-751-...  1871322
# 133  [{'tags': {'includes': ['Akkermansia sp. Pyt']...  1679444
# 134  [{'leaf': 1, 'id': '1325564', 'tags': {'type_m...  1325564
# 135  [{'id': '539', 'tags': {'scientific_name': ['E...      539
#
#                                                lineage superkingdom  \
# 0    [{'tags': {'name': ['Escherichia'], 'scientifi...     Bacteria
# 1    [{'id': '286', 'tags': {'includes': ['Chryseom...     Bacteria
# 2    [{'parent': {'leaf': 0, 'tags': {'name': ['Geo...     Bacteria
# 3    [{'parent': {'name': 'Aquificaceae', 'leaf': 0...     Bacteria
# 4    [{'parent': {'scientific_name': 'Bacillaceae',...     Bacteria
# ..                                                 ...          ...
# 131  [{'scientific_name': 'Treponema', 'tags': {'na...     Bacteria
# 132  [{'scientific_name': 'Chlamydiales', 'tags': {...     Bacteria
# 133  [{'leaf': 0, 'children': [{'tags': {'authority...     Bacteria
# 134  [{'leaf': 0, 'name': 'Nitrospira', 'children':...     Bacteria
# 135  [{'tags': {'authority': ['Eikenella Jackson an...     Bacteria
#
#               phylum                class               order  \
# 0     Proteobacteria  Gammaproteobacteria    Enterobacterales
# 1     Proteobacteria  Gammaproteobacteria     Pseudomonadales
# 2     Proteobacteria  Deltaproteobacteria  Desulfuromonadales
# 3          Aquificae          Aquificales        Aquificaceae
# 4         Firmicutes              Bacilli          Bacillales
# ..               ...                  ...                 ...
# 131     Spirochaetes       Spirochaetales     Treponemataceae
# 132       Chlamydiae         Chlamydiales                None
# 133  Verrucomicrobia     Verrucomicrobiae  Verrucomicrobiales
# 134      Nitrospirae        Nitrospirales      Nitrospiraceae
# 135   Proteobacteria   Betaproteobacteria        Neisseriales
#
#                  family
# 0    Enterobacteriaceae
# 1      Pseudomonadaceae
# 2        Geobacteraceae
# 3               Aquifex
# 4           Bacillaceae
# ..                  ...
# 131           Treponema
# 132                None
# 133     Akkermansiaceae
# 134          Nitrospira
# 135       Neisseriaceae
#
# [136 rows x 10 columns]

# %%
HFSP_phy_genome_org_df.to_csv("/mnt/researchdrive/Kaustubh/HFSP-Flagellar_proteins/data/sequences/uniq_genome_accession_organism_name_taxa_info.csv")

# %%
HFSP_phy_genome_org_df[["Organism_Name","superkingdom","phylum","class","order","family"]].to_csv("/mnt/researchdrive/Kaustubh/HFSP-Flagellar_proteins/analysis/OGT_prediction/prediction_HFSP/species_taxonomic.txt", index=False, sep='\t')

# %% [markdown]
# ## This part is for the Species Tree genomes taxa info

# %%
HFSP_genome_info = pd.read_csv("../data/species_tree/genomes_taxa_info.csv")
HFSP_genome_info
# Out:
#                          assembly                               organismName  \
# 0        GCA_000005845.2_ASM584v2  Escherichia_coli_str._K-12_substr._MG1655
# 1        GCA_000006765.1_ASM676v1                Pseudomonas_aeruginosa_PAO1
# 2        GCA_000007025.1_ASM702v1           Rickettsia_conorii_str._Malish_7
# 3        GCA_000007205.1_ASM720v1                Chlamydia_pneumoniae_TW-183
# 4        GCA_000007365.1_ASM736v1                Buchnera_aphidicola_str._Sg
# ..                            ...                                        ...
# 192   GCF_003812925.1_ASM381292v1                         Klebsiella_oxytoca
# 193   GCF_006874605.1_ASM687460v1                      Bacteriovorax_stolpii
# 194   GCF_006874645.1_ASM687464v1                      Bdellovibrio_sp._ZAP7
# 195  GCF_011300455.1_ASM1130045v1                        Sphingomonas_piscis
# 196  GCF_022814725.1_ASM2281472v1                   Bdellovibrio_reynosensis
#
#        taxid
# 0     511145
# 1     208964
# 2     272944
# 3     182082
# 4     198804
# ..       ...
# 192      571
# 193      960
# 194  2231053
# 195  2714943
# 196  2835041
#
# [197 rows x 3 columns]

# %%
HFSP_genome_info["lineage"] = HFSP_genome_info["taxid"].apply(get_taxonomic_lineage)
HFSP_genome_info["superkingdom"] = HFSP_genome_info["lineage"].apply(get_superkingdom)
HFSP_genome_info["phylum"] = HFSP_genome_info["lineage"].apply(get_phylum)
HFSP_genome_info["class"] = HFSP_genome_info["lineage"].apply(get_class)
HFSP_genome_info["order"] = HFSP_genome_info["lineage"].apply(get_order)
HFSP_genome_info["family"] = HFSP_genome_info["lineage"].apply(get_family)

# %%
HFSP_genome_info
# Out:
#                          assembly                               organismName  \
# 0        GCA_000005845.2_ASM584v2  Escherichia_coli_str._K-12_substr._MG1655
# 1        GCA_000006765.1_ASM676v1                Pseudomonas_aeruginosa_PAO1
# 2        GCA_000007025.1_ASM702v1           Rickettsia_conorii_str._Malish_7
# 3        GCA_000007205.1_ASM720v1                Chlamydia_pneumoniae_TW-183
# 4        GCA_000007365.1_ASM736v1                Buchnera_aphidicola_str._Sg
# ..                            ...                                        ...
# 192   GCF_003812925.1_ASM381292v1                         Klebsiella_oxytoca
# 193   GCF_006874605.1_ASM687460v1                      Bacteriovorax_stolpii
# 194   GCF_006874645.1_ASM687464v1                      Bdellovibrio_sp._ZAP7
# 195  GCF_011300455.1_ASM1130045v1                        Sphingomonas_piscis
# 196  GCF_022814725.1_ASM2281472v1                   Bdellovibrio_reynosensis
#
#        taxid                                            lineage superkingdom  \
# 0     511145  [{'tags': {'name': ['Escherichia'], 'scientifi...     Bacteria
# 1     208964  [{'children': [{'scientific_name': 'Pseudomona...     Bacteria
# 2     272944  [{'children': [{'scientific_name': 'Rickettsia...     Bacteria
# 3     182082  [{'leaf': 0, 'children': [{'scientific_name': ...     Bacteria
# 4     198804  [{'id': '32199', 'tags': {'scientific_name': [...     Bacteria
# ..       ...                                                ...          ...
# 192      571  [{'leaf': 0, 'children': [{'scientific_name': ...     Bacteria
# 193      960  [{'scientific_name': 'Bacteriovorax', 'leaf': ...     Bacteria
# 194  2231053  [{'parent': {'tags': {'authority': ['Bdellovib...     Bacteria
# 195  2714943  [{'id': '2714943', 'tags': {'scientific_name':...     Bacteria
# 196  2835041  [{'tags': {'scientific_name': ['Bdellovibrio s...     Bacteria
#
#              phylum                class              order  \
# 0    Proteobacteria  Gammaproteobacteria   Enterobacterales
# 1    Proteobacteria  Gammaproteobacteria    Pseudomonadales
# 2    Proteobacteria  Alphaproteobacteria      Rickettsiales
# 3        Chlamydiae         Chlamydiales      Chlamydiaceae
# 4    Proteobacteria  Gammaproteobacteria   Enterobacterales
# ..              ...                  ...                ...
# 192  Proteobacteria  Gammaproteobacteria   Enterobacterales
# 193  Proteobacteria          Oligoflexia  Bacteriovoracales
# 194  Proteobacteria          Oligoflexia  Bdellovibrionales
# 195  Proteobacteria  Alphaproteobacteria   Sphingomonadales
# 196  Proteobacteria          Oligoflexia  Bdellovibrionales
#
#                             family
# 0               Enterobacteriaceae
# 1                 Pseudomonadaceae
# 2                   Rickettsiaceae
# 3    Chlamydia/Chlamydophila group
# 4                      Erwiniaceae
# ..                             ...
# 192             Enterobacteriaceae
# 193             Bacteriovoracaceae
# 194             Bdellovibrionaceae
# 195              Sphingomonadaceae
# 196             Bdellovibrionaceae
#
# [197 rows x 9 columns]

# %%
HFSP_genome_info[["organismName","superkingdom","phylum","class","order","family"]].to_csv("/mnt/researchdrive/Kaustubh/HFSP-Flagellar_proteins/analysis/OGT_prediction/prediction_HFSP_species_tree/species_taxonomic.txt", index=False, sep='\t')
